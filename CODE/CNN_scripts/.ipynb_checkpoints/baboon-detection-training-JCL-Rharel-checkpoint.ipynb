# %%
import torch, torchvision
import detectron2
import os

from detectron2.utils.logger import setup_logger

import numpy as np
import cv2
import random

from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.evaluation import COCOEvaluator, DatasetEvaluators
# Out:
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath

# %%
print( np.__version__)
# Out:
# 1.17.4

# %%
import matplotlib.pyplot as plt

# %%
name = 'For_rharel'

# %%
def cv2_imshow(im):
    cv2.imshow('fiile', im)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
## root on my local computer
# root = 'C:/Users/cloftus/Documents/thermal_baboons/annotations/'

## root on the server
root = 'X:/baboon/working/video/feeding'

from detectron2.data.datasets import register_coco_instances

output_folder = root
coco_annotation_file = os.path.join(output_folder, 'GH034137.json')
output_image_folder = os.path.join(output_folder, 'images')

register_coco_instances("train",  {}, coco_annotation_file, output_image_folder ) 
register_coco_instances("val", {}, coco_annotation_file, output_image_folder )

# %%
train_metadata = MetadataCatalog.get("train")

# %%
MetadataCatalog.get("val").evaluator_type
# Out:
# 'coco'

# %%
train_dicts = DatasetCatalog.get("train")
val_dicts = DatasetCatalog.get("val")

# %%
# for d in val_dicts:
#     img = cv2.imread(d["file_name"])
#     visualizer = Visualizer(img[:, :, ::-1], metadata=train_metadata, scale=0.5)
#     vis = visualizer.draw_dataset_dict(d)
#     cv2_imshow(vis.get_image()[:, :, ::-1])

# %%
# %matplotlib inline

for d in random.sample(train_dicts, 3):
# for d in train_dicts:
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=train_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    plt.figure(figsize=(10,10))
    plt.imshow(vis.get_image())
    plt.savefig('')

# %%
##base root on my local computer
#base_root = 'C:/Users/cloftus/'

##base root on the HiWi computer
base_root = 'C:/Users/meerkat/'

os.chdir( base_root + 'detectron2-windows/configs/COCO-Detection/' )

os.listdir()
# Out:
# ['faster_rcnn_R_101_C4_3x.yaml',
#  'faster_rcnn_R_101_DC5_3x.yaml',
#  'faster_rcnn_R_101_FPN_3x.yaml',
#  'faster_rcnn_R_50_C4_1x.yaml',
#  'faster_rcnn_R_50_C4_3x.yaml',
#  'faster_rcnn_R_50_DC5_1x.yaml',
#  'faster_rcnn_R_50_DC5_3x.yaml',
#  'faster_rcnn_R_50_FPN_1x.yaml',
#  'faster_rcnn_R_50_FPN_3x.yaml',
#  'faster_rcnn_X_101_32x8d_FPN_3x.yaml',
#  'fast_rcnn_R_50_FPN_1x.yaml',
#  'output',
#  'retinanet_R_101_FPN_3x.yaml',
#  'retinanet_R_50_FPN_1x.yaml',
#  'retinanet_R_50_FPN_3x.yaml',
#  'rpn_R_50_C4_1x.yaml',
#  'rpn_R_50_FPN_1x.yaml']

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
import os

cfg = get_cfg()
cfg.merge_from_file(
    base_root + 'detectron2-windows/configs/COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml'
)



cfg.DATASETS.TRAIN = ("train",)
cfg.DATASETS.TEST = ("val",)
cfg.DATALOADER.NUM_WORKERS = 6
cfg.DATALOADER.ASPECT_RATIO_GROUPING = False

cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(
    "COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"
)
cfg.SOLVER.IMS_PER_BATCH = 8
cfg.SOLVER.BASE_LR = 0.019
cfg.SOLVER.MAX_ITER = (2000)
cfg.SOLVER.WARMUP_ITERS = 100
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = (256)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 3

cfg.TEST.EVAL_PERIOD = 100
cfg.TEST.DETECTIONS_PER_IMAGE = 200

cfg.INPUT.MIN_SIZE_TRAIN = (0)
cfg.INPUT.MIN_SIZE_TEST = (0)
cfg.INPUT.MAX_SIZE_TRAIN = (2871)
cfg.INPUT.MAX_SIZE_TEST = (2871)

cfg.INPUT.CROP.ENABLED = True
cfg.INPUT.CROP.TYPE = "absolute"
cfg.INPUT.CROP.SIZE = (720.0, 1280.0)
cfg.INPUT.VER_FLIP = True
cfg.INPUT.CONTRAST = True
cfg.INPUT.CONTRAST_RANGE = (.5, 1.5)
cfg.INPUT.BRIGHTNESS = True
cfg.INPUT.BRIGHTNESS_RANGE = (.4, 1.3)



cfg.OUTPUT_DIR = os.path.join(cfg.OUTPUT_DIR, '{}_maxiter-{}_lr-{}_detectPerIm-{}_minsize-{}_batchsize-{}'.format(
    name, cfg.SOLVER.MAX_ITER, cfg.SOLVER.BASE_LR, cfg.TEST.DETECTIONS_PER_IMAGE, 
    np.min(cfg.INPUT.MIN_SIZE_TRAIN), cfg.SOLVER.IMS_PER_BATCH))

# %%
cfg.OUTPUT_DIR
# Out:
# './output\\For_rharel_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8'

# %%
print(cfg.INPUT)
# Out:
# BRIGHTNESS: True
# BRIGHTNESS_RANGE: (0.4, 1.3)
# CONTRAST: True
# CONTRAST_RANGE: (0.5, 1.5)
# CROP:
#   ENABLED: True
#   SIZE: (720.0, 1280.0)
#   TYPE: absolute
# FORMAT: BGR
# MASK_FORMAT: polygon
# MAX_SIZE_TEST: 2871
# MAX_SIZE_TRAIN: 2871
# MIN_SIZE_TEST: 0
# MIN_SIZE_TRAIN: 0
# MIN_SIZE_TRAIN_SAMPLING: choice
# VER_FLIP: True

# %%
# mapper = MyDatasetMapper(cfg)
# loader = build_detection_train_loader(cfg, mapper=mapper)
# loader_iter = iter(loader)

# %%
# import matplotlib.pyplot as plt

# for im_num in range(4):

#     batch = next(loader_iter)

#     for im_dict in batch:
#         image = im_dict['image'].numpy()
#         image = np.transpose(image, [1, 2, 0])
#         image /= 255
#         cv2_imshow(image)

# %%
from detectron2.data import build_detection_train_loader
from detectron2.data import detection_utils as utils
from detectron2.data import transforms as T
from detectron2.data.dataset_mapper import DatasetMapper
import copy

import logging

import torch

class MyDatasetMapper(DatasetMapper):
    
    def __init__(self, cfg, is_train=True):
        if cfg.INPUT.CROP.ENABLED and is_train:
            self.crop_gen = T.RandomCrop(cfg.INPUT.CROP.TYPE, cfg.INPUT.CROP.SIZE)
            logging.getLogger(__name__).info("CropGen used in training: " + str(self.crop_gen))
        else:
            self.crop_gen = None

        self.tfm_gens = utils.build_transform_gen(cfg, is_train)
        
        if cfg.INPUT.VER_FLIP:
            self.tfm_gens.append(T.RandomFlip(vertical=True, horizontal=False))
        if cfg.INPUT.CONTRAST:
            self.tfm_gens.append(T.RandomContrast(*cfg.INPUT.CONTRAST_RANGE))
        if cfg.INPUT.BRIGHTNESS:
            self.tfm_gens.append(T.RandomBrightness(*cfg.INPUT.BRIGHTNESS_RANGE))
            
        logger = logging.getLogger(__name__)
        logger.info("TransformGens used in training: " + str(self.tfm_gens))

        # fmt: off
        self.img_format     = cfg.INPUT.FORMAT
        self.mask_on        = cfg.MODEL.MASK_ON
        self.mask_format    = cfg.INPUT.MASK_FORMAT
        self.keypoint_on    = cfg.MODEL.KEYPOINT_ON
        self.load_proposals = cfg.MODEL.LOAD_PROPOSALS
        # fmt: on
        
        if self.keypoint_on and is_train:
            # Flip only makes sense in training
            self.keypoint_hflip_indices = utils.create_keypoint_hflip_indices(cfg.DATASETS.TRAIN)
        else:
            self.keypoint_hflip_indices = None

        if self.load_proposals:
            self.min_box_side_len = cfg.MODEL.PROPOSAL_GENERATOR.MIN_SIZE
            self.proposal_topk = (
                cfg.DATASETS.PRECOMPUTED_PROPOSAL_TOPK_TRAIN
                if is_train
                else cfg.DATASETS.PRECOMPUTED_PROPOSAL_TOPK_TEST
            )

        self.is_train = is_train
    
    def __call__(self, dataset_dict):
        """
        Args:
            dataset_dict (dict): Metadata of one image, in Detectron2 Dataset format.
        Returns:
            dict: a format that builtin models in detectron2 accept
        """
        dataset_dict = copy.deepcopy(dataset_dict)  # it will be modified by code below
        # USER: Write your own image loading if it's not from a file
        image = utils.read_image(dataset_dict["file_name"], format=self.img_format)
        utils.check_image_size(dataset_dict, image)

        if "annotations" not in dataset_dict:
            image, transforms = T.apply_transform_gens(
                ([self.crop_gen] if self.crop_gen else []) + self.tfm_gens, image
            )
        else:
            # Crop around an instance if there are instances in the image.
            # USER: Remove if you don't use cropping
            if self.crop_gen:
                crop_tfm = utils.gen_crop_transform_with_instance(
                    self.crop_gen.get_crop_size(image.shape[:2]),
                    image.shape[:2],
                    np.random.choice(dataset_dict["annotations"]),
                )
                image = crop_tfm.apply_image(image)
            image, transforms = T.apply_transform_gens(self.tfm_gens, image)
            if self.crop_gen:
                transforms = crop_tfm + transforms

        image_shape = image.shape[:2]  # h, w

        # Pytorch's dataloader is efficient on torch.Tensor due to shared-memory,
        # but not efficient on large generic data structures due to the use of pickle & mp.Queue.
        # Therefore it's important to use torch.Tensor.
        dataset_dict["image"] = torch.as_tensor(
            image.transpose(2, 0, 1).astype("float32")
        ).contiguous()
        # Can use uint8 if it turns out to be slow some day

        if not self.is_train:
            dataset_dict.pop("annotations", None)
            dataset_dict.pop("sem_seg_file_name", None)
            return dataset_dict

        if "annotations" in dataset_dict:
            # USER: Modify this if you want to keep them for some reason.
            for anno in dataset_dict["annotations"]:
                if not self.mask_on:
                    anno.pop("segmentation", None)
                if not self.keypoint_on:
                    anno.pop("keypoints", None)
                    
            # USER: Implement additional transformations if you have other types of data
            annos = [
                utils.transform_instance_annotations(
                    obj, transforms, image_shape, keypoint_hflip_indices=self.keypoint_hflip_indices
                )
                for obj in dataset_dict.pop("annotations")
                if obj.get("iscrowd", 0) == 0
            ]
            instances = utils.annotations_to_instances(
                annos, image_shape, mask_format=self.mask_format
            )

            # Create a tight bounding box from masks, useful when image is cropped
            if self.crop_gen and instances.has("gt_masks"):
                instances.gt_boxes = instances.gt_masks.get_bounding_boxes()
            dataset_dict["instances"] = utils.filter_empty_instances(instances)

        return dataset_dict


class Trainer(DefaultTrainer):
    """ Implements build_evaluator. 
    Only for coco.
    """
    
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
        evaluator_type = MetadataCatalog.get(dataset_name).evaluator_type
        if evaluator_type == "coco":
            return COCOEvaluator(dataset_name, cfg, True, output_folder)

        else:
            raise NotImplementedError("Only coco evaluators are currently implemented. Change build_evaluator().")
            
            
    @classmethod
    def build_train_loader(cls, cfg):
        """
        Returns:
            iterable
        It now calls :func:`detectron2.data.build_detection_train_loader` but now with mapper.
        Overwrite it if you'd like a different data loader.
        """
        
        mapper = MyDatasetMapper(cfg)
        
        return build_detection_train_loader(cfg, mapper=mapper)

# %%
os.chdir( 'C:/Users/meerkat/Documents/GitHub/thermal_baboon/CNN_scripts')

# %%
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = Trainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/26 11:12:01 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#     )
#   )
# )
# [02/26 11:12:01 d2.data.datasets.coco]: Loaded 70 images in COCO format from X:/baboon/working/video/feeding\GH034137.json
# [02/26 11:12:01 d2.data.build]: Removed 0 images with no usable annotations. 70 images left.
# [02/26 11:12:01 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    ape     | 1062         |
# |            |              |
# [02/26 11:12:01 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/26 11:12:01 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/26 11:12:01 d2.data.build]: Using training sampler TrainingSampler
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (12, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (12,) in the model! You might want to double check if this is expected.
# [02/26 11:12:02 d2.engine.train_loop]: Starting training from iteration 0
# c:\users\meerkat\detectron2-windows\detectron2\layers\wrappers.py:226: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  ..\torch\csrc\utils\python_arg_parser.cpp:766.)
#   return x.nonzero().unbind(1)
# [02/26 11:12:46 d2.utils.events]:  eta: 0:34:06  iter: 19  total_loss: 1.484  loss_cls: 0.553  loss_box_reg: 0.778  loss_rpn_cls: 0.119  loss_rpn_loc: 0.051  time: 1.1914  data_time: 1.0271  lr: 0.003625  max_mem: 8056M
# [02/26 11:13:08 d2.utils.events]:  eta: 0:33:48  iter: 39  total_loss: 0.827  loss_cls: 0.207  loss_box_reg: 0.515  loss_rpn_cls: 0.048  loss_rpn_loc: 0.050  time: 1.1599  data_time: 0.0929  lr: 0.007422  max_mem: 8056M
# [02/26 11:13:30 d2.utils.events]:  eta: 0:33:26  iter: 59  total_loss: 0.720  loss_cls: 0.192  loss_box_reg: 0.469  loss_rpn_cls: 0.032  loss_rpn_loc: 0.037  time: 1.1362  data_time: 0.0549  lr: 0.011218  max_mem: 8056M
# [02/26 11:13:51 d2.utils.events]:  eta: 0:33:04  iter: 79  total_loss: 0.642  loss_cls: 0.167  loss_box_reg: 0.413  loss_rpn_cls: 0.028  loss_rpn_loc: 0.036  time: 1.1106  data_time: 0.0012  lr: 0.015014  max_mem: 8056M
# [02/26 11:14:12 d2.data.datasets.coco]: Loaded 70 images in COCO format from X:/baboon/working/video/feeding\GH034137.json
# [02/26 11:14:12 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/26 11:14:12 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/26 11:14:12 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/26 11:14:12 d2.evaluation.evaluator]: Start inference on 70 images
# [02/26 11:14:16 d2.evaluation.evaluator]: Inference done 11/70. 0.2440 s / img. ETA=0:00:14
# [02/26 11:14:21 d2.evaluation.evaluator]: Inference done 31/70. 0.2472 s / img. ETA=0:00:09
# [02/26 11:14:26 d2.evaluation.evaluator]: Inference done 51/70. 0.2494 s / img. ETA=0:00:04
# [02/26 11:14:31 d2.evaluation.evaluator]: Total inference time: 0:00:16.530545 (0.254316 s / img per device, on 1 devices)
# [02/26 11:14:31 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:16 (0.248173 s / img per device, on 1 devices)
# [02/26 11:14:31 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 11:14:31 d2.evaluation.coco_evaluation]: Saving results to ./output\For_rharel_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/26 11:14:31 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.537
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.961
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.548
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.378
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.534
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.580
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.045
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.609
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.608
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.646
# [02/26 11:14:31 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 53.680 | 96.067 | 54.765 | 37.754 | 53.395 | 57.956 |
# [02/26 11:14:31 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/26 11:14:31 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 11:14:31 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 11:14:31 d2.evaluation.testing]: copypaste: 53.6796,96.0674,54.7648,37.7541,53.3950,57.9556
# [02/26 11:14:31 d2.utils.events]:  eta: 0:32:44  iter: 99  total_loss: 0.683  loss_cls: 0.171  loss_box_reg: 0.438  loss_rpn_cls: 0.034  loss_rpn_loc: 0.039  time: 1.0963  data_time: 0.0016  lr: 0.018810  max_mem: 8056M
# [02/26 11:14:52 d2.utils.events]:  eta: 0:32:28  iter: 119  total_loss: 0.734  loss_cls: 0.182  loss_box_reg: 0.472  loss_rpn_cls: 0.028  loss_rpn_loc: 0.047  time: 1.0899  data_time: 0.0017  lr: 0.019000  max_mem: 8056M
# [02/26 11:15:13 d2.utils.events]:  eta: 0:32:11  iter: 139  total_loss: 0.633  loss_cls: 0.139  loss_box_reg: 0.418  loss_rpn_cls: 0.026  loss_rpn_loc: 0.037  time: 1.0851  data_time: 0.0012  lr: 0.019000  max_mem: 8056M
# [02/26 11:15:34 d2.utils.events]:  eta: 0:31:50  iter: 159  total_loss: 0.658  loss_cls: 0.138  loss_box_reg: 0.425  loss_rpn_cls: 0.039  loss_rpn_loc: 0.055  time: 1.0795  data_time: 0.0018  lr: 0.019000  max_mem: 8056M
# [02/26 11:15:55 d2.utils.events]:  eta: 0:31:27  iter: 179  total_loss: 0.646  loss_cls: 0.142  loss_box_reg: 0.427  loss_rpn_cls: 0.031  loss_rpn_loc: 0.046  time: 1.0746  data_time: 0.0017  lr: 0.019000  max_mem: 8056M
# [02/26 11:16:16 d2.data.datasets.coco]: Loaded 70 images in COCO format from X:/baboon/working/video/feeding\GH034137.json
# [02/26 11:16:16 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/26 11:16:16 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/26 11:16:16 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/26 11:16:16 d2.evaluation.evaluator]: Start inference on 70 images
# [02/26 11:16:20 d2.evaluation.evaluator]: Inference done 11/70. 0.2549 s / img. ETA=0:00:15
# [02/26 11:16:25 d2.evaluation.evaluator]: Inference done 32/70. 0.2483 s / img. ETA=0:00:09
# [02/26 11:16:30 d2.evaluation.evaluator]: Inference done 53/70. 0.2468 s / img. ETA=0:00:04
# [02/26 11:16:34 d2.evaluation.evaluator]: Total inference time: 0:00:16.394808 (0.252228 s / img per device, on 1 devices)
# [02/26 11:16:34 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:16 (0.246159 s / img per device, on 1 devices)
# [02/26 11:16:34 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 11:16:34 d2.evaluation.coco_evaluation]: Saving results to ./output\For_rharel_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/26 11:16:35 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.04 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.558
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.946
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.624
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.452
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.544
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.614
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.431
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.637
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.629
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.683
# [02/26 11:16:35 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 55.832 | 94.621 | 62.405 | 45.186 | 54.414 | 61.420 |
# [02/26 11:16:35 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/26 11:16:35 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 11:16:35 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 11:16:35 d2.evaluation.testing]: copypaste: 55.8323,94.6211,62.4051,45.1861,54.4140,61.4198
# [02/26 11:16:35 d2.utils.events]:  eta: 0:31:08  iter: 199  total_loss: 0.615  loss_cls: 0.145  loss_box_reg: 0.380  loss_rpn_cls: 0.032  loss_rpn_loc: 0.050  time: 1.0714  data_time: 0.0008  lr: 0.019000  max_mem: 8056M
# [02/26 11:16:56 d2.utils.events]:  eta: 0:30:50  iter: 219  total_loss: 0.618  loss_cls: 0.146  loss_box_reg: 0.401  loss_rpn_cls: 0.023  loss_rpn_loc: 0.033  time: 1.0703  data_time: 0.0017  lr: 0.019000  max_mem: 8056M
# [02/26 11:17:17 d2.utils.events]:  eta: 0:30:31  iter: 239  total_loss: 0.639  loss_cls: 0.152  loss_box_reg: 0.406  loss_rpn_cls: 0.027  loss_rpn_loc: 0.049  time: 1.0680  data_time: 0.0015  lr: 0.019000  max_mem: 8056M
# [02/26 11:17:37 d2.utils.events]:  eta: 0:30:09  iter: 259  total_loss: 0.601  loss_cls: 0.152  loss_box_reg: 0.386  loss_rpn_cls: 0.025  loss_rpn_loc: 0.042  time: 1.0657  data_time: 0.0013  lr: 0.019000  max_mem: 8056M
# [02/26 11:17:58 d2.utils.events]:  eta: 0:29:48  iter: 279  total_loss: 0.613  loss_cls: 0.149  loss_box_reg: 0.374  loss_rpn_cls: 0.025  loss_rpn_loc: 0.037  time: 1.0636  data_time: 0.0015  lr: 0.019000  max_mem: 8056M
# [02/26 11:18:19 d2.data.datasets.coco]: Loaded 70 images in COCO format from X:/baboon/working/video/feeding\GH034137.json
# [02/26 11:18:19 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/26 11:18:19 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/26 11:18:19 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/26 11:18:19 d2.evaluation.evaluator]: Start inference on 70 images
# [02/26 11:18:23 d2.evaluation.evaluator]: Inference done 11/70. 0.2445 s / img. ETA=0:00:14
# [02/26 11:18:28 d2.evaluation.evaluator]: Inference done 31/70. 0.2470 s / img. ETA=0:00:09
# [02/26 11:18:33 d2.evaluation.evaluator]: Inference done 51/70. 0.2519 s / img. ETA=0:00:04
# [02/26 11:18:38 d2.evaluation.evaluator]: Total inference time: 0:00:16.905287 (0.260081 s / img per device, on 1 devices)
# [02/26 11:18:38 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:16 (0.253933 s / img per device, on 1 devices)
# [02/26 11:18:38 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 11:18:38 d2.evaluation.coco_evaluation]: Saving results to ./output\For_rharel_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/26 11:18:38 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.584
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.974
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.662
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.467
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.570
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.642
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.443
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.646
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.693
# [02/26 11:18:39 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 58.398 | 97.371 | 66.248 | 46.738 | 57.015 | 64.196 |
# [02/26 11:18:39 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/26 11:18:39 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 11:18:39 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 11:18:39 d2.evaluation.testing]: copypaste: 58.3978,97.3709,66.2483,46.7375,57.0151,64.1959
# [02/26 11:18:39 d2.utils.events]:  eta: 0:29:27  iter: 299  total_loss: 0.560  loss_cls: 0.133  loss_box_reg: 0.368  loss_rpn_cls: 0.021  loss_rpn_loc: 0.038  time: 1.0624  data_time: 0.0016  lr: 0.019000  max_mem: 8056M
# [02/26 11:19:00 d2.utils.events]:  eta: 0:29:07  iter: 319  total_loss: 0.570  loss_cls: 0.128  loss_box_reg: 0.369  loss_rpn_cls: 0.027  loss_rpn_loc: 0.037  time: 1.0619  data_time: 0.0015  lr: 0.019000  max_mem: 8056M
# [02/26 11:19:21 d2.utils.events]:  eta: 0:28:48  iter: 339  total_loss: 0.583  loss_cls: 0.133  loss_box_reg: 0.374  loss_rpn_cls: 0.035  loss_rpn_loc: 0.055  time: 1.0615  data_time: 0.0014  lr: 0.019000  max_mem: 8056M
# [02/26 11:19:42 d2.utils.events]:  eta: 0:28:27  iter: 359  total_loss: 0.570  loss_cls: 0.137  loss_box_reg: 0.370  loss_rpn_cls: 0.023  loss_rpn_loc: 0.047  time: 1.0606  data_time: 0.0015  lr: 0.019000  max_mem: 8056M
# [02/26 11:20:03 d2.utils.events]:  eta: 0:28:08  iter: 379  total_loss: 0.597  loss_cls: 0.148  loss_box_reg: 0.361  loss_rpn_cls: 0.025  loss_rpn_loc: 0.046  time: 1.0604  data_time: 0.0016  lr: 0.019000  max_mem: 8056M
# [02/26 11:20:24 d2.data.datasets.coco]: Loaded 70 images in COCO format from X:/baboon/working/video/feeding\GH034137.json
# [02/26 11:20:24 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/26 11:20:24 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/26 11:20:24 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/26 11:20:24 d2.evaluation.evaluator]: Start inference on 70 images
# [02/26 11:20:28 d2.evaluation.evaluator]: Inference done 11/70. 0.2451 s / img. ETA=0:00:14
# [02/26 11:20:33 d2.evaluation.evaluator]: Inference done 31/70. 0.2466 s / img. ETA=0:00:09
# [02/26 11:20:38 d2.evaluation.evaluator]: Inference done 52/70. 0.2455 s / img. ETA=0:00:04
# [02/26 11:20:43 d2.evaluation.evaluator]: Total inference time: 0:00:16.364142 (0.251756 s / img per device, on 1 devices)
# [02/26 11:20:43 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:15 (0.245647 s / img per device, on 1 devices)
# [02/26 11:20:43 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 11:20:43 d2.evaluation.coco_evaluation]: Saving results to ./output\For_rharel_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/26 11:20:43 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.627
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.976
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.739
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.483
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.617
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.678
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.471
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.687
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.552
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.682
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.729
# [02/26 11:20:43 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 62.675 | 97.636 | 73.898 | 48.259 | 61.745 | 67.754 |
# [02/26 11:20:43 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/26 11:20:43 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 11:20:43 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 11:20:43 d2.evaluation.testing]: copypaste: 62.6754,97.6363,73.8977,48.2594,61.7446,67.7542
# [02/26 11:20:43 d2.utils.events]:  eta: 0:27:47  iter: 399  total_loss: 0.555  loss_cls: 0.133  loss_box_reg: 0.365  loss_rpn_cls: 0.020  loss_rpn_loc: 0.035  time: 1.0599  data_time: 0.0014  lr: 0.019000  max_mem: 8056M
# [02/26 11:21:04 d2.utils.events]:  eta: 0:27:27  iter: 419  total_loss: 0.557  loss_cls: 0.135  loss_box_reg: 0.372  loss_rpn_cls: 0.026  loss_rpn_loc: 0.038  time: 1.0592  data_time: 0.0013  lr: 0.019000  max_mem: 8056M
# [02/26 11:21:24 d2.utils.events]:  eta: 0:27:06  iter: 439  total_loss: 0.531  loss_cls: 0.122  loss_box_reg: 0.342  loss_rpn_cls: 0.023  loss_rpn_loc: 0.032  time: 1.0583  data_time: 0.0012  lr: 0.019000  max_mem: 8056M
# [02/26 11:21:45 d2.utils.events]:  eta: 0:26:45  iter: 459  total_loss: 0.531  loss_cls: 0.119  loss_box_reg: 0.339  loss_rpn_cls: 0.022  loss_rpn_loc: 0.045  time: 1.0576  data_time: 0.0012  lr: 0.019000  max_mem: 8056M
# [02/26 11:22:06 d2.utils.events]:  eta: 0:26:25  iter: 479  total_loss: 0.527  loss_cls: 0.114  loss_box_reg: 0.362  loss_rpn_cls: 0.013  loss_rpn_loc: 0.030  time: 1.0575  data_time: 0.0017  lr: 0.019000  max_mem: 8056M
# [02/26 11:22:28 d2.data.datasets.coco]: Loaded 70 images in COCO format from X:/baboon/working/video/feeding\GH034137.json
# [02/26 11:22:28 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/26 11:22:28 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/26 11:22:28 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/26 11:22:28 d2.evaluation.evaluator]: Start inference on 70 images
# [02/26 11:22:31 d2.evaluation.evaluator]: Inference done 11/70. 0.2556 s / img. ETA=0:00:15
# [02/26 11:22:37 d2.evaluation.evaluator]: Inference done 31/70. 0.2519 s / img. ETA=0:00:09
# [02/26 11:22:42 d2.evaluation.evaluator]: Inference done 51/70. 0.2504 s / img. ETA=0:00:04
# [02/26 11:22:47 d2.evaluation.evaluator]: Total inference time: 0:00:16.776857 (0.258105 s / img per device, on 1 devices)
# [02/26 11:22:47 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:16 (0.251818 s / img per device, on 1 devices)
# [02/26 11:22:47 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 11:22:47 d2.evaluation.coco_evaluation]: Saving results to ./output\For_rharel_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/26 11:22:47 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.604
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.977
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.700
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.488
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.596
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.660
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.460
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.673
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.668
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.710
# [02/26 11:22:47 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 60.367 | 97.668 | 69.951 | 48.830 | 59.557 | 66.036 |
# [02/26 11:22:47 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/26 11:22:47 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 11:22:47 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 11:22:47 d2.evaluation.testing]: copypaste: 60.3671,97.6685,69.9507,48.8297,59.5571,66.0363
# [02/26 11:22:47 d2.utils.events]:  eta: 0:26:05  iter: 499  total_loss: 0.556  loss_cls: 0.122  loss_box_reg: 0.351  loss_rpn_cls: 0.024  loss_rpn_loc: 0.034  time: 1.0573  data_time: 0.0018  lr: 0.019000  max_mem: 8056M
# [02/26 11:23:08 d2.utils.events]:  eta: 0:25:44  iter: 519  total_loss: 0.503  loss_cls: 0.120  loss_box_reg: 0.332  loss_rpn_cls: 0.018  loss_rpn_loc: 0.029  time: 1.0573  data_time: 0.0015  lr: 0.019000  max_mem: 8056M
# [02/26 11:23:29 d2.utils.events]:  eta: 0:25:23  iter: 539  total_loss: 0.565  loss_cls: 0.123  loss_box_reg: 0.352  loss_rpn_cls: 0.023  loss_rpn_loc: 0.036  time: 1.0568  data_time: 0.0017  lr: 0.019000  max_mem: 8056M
# [02/26 11:23:50 d2.utils.events]:  eta: 0:25:02  iter: 559  total_loss: 0.530  loss_cls: 0.125  loss_box_reg: 0.343  loss_rpn_cls: 0.029  loss_rpn_loc: 0.036  time: 1.0560  data_time: 0.0015  lr: 0.019000  max_mem: 8056M
# [02/26 11:24:10 d2.utils.events]:  eta: 0:24:41  iter: 579  total_loss: 0.522  loss_cls: 0.120  loss_box_reg: 0.360  loss_rpn_cls: 0.016  loss_rpn_loc: 0.033  time: 1.0553  data_time: 0.0014  lr: 0.019000  max_mem: 8056M
# [02/26 11:24:31 d2.data.datasets.coco]: Loaded 70 images in COCO format from X:/baboon/working/video/feeding\GH034137.json
# [02/26 11:24:31 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/26 11:24:31 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/26 11:24:31 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/26 11:24:31 d2.evaluation.evaluator]: Start inference on 70 images
# [02/26 11:24:35 d2.evaluation.evaluator]: Inference done 11/70. 0.2451 s / img. ETA=0:00:14
# [02/26 11:24:40 d2.evaluation.evaluator]: Inference done 32/70. 0.2447 s / img. ETA=0:00:09
# [02/26 11:24:45 d2.evaluation.evaluator]: Inference done 53/70. 0.2448 s / img. ETA=0:00:04
# [02/26 11:24:50 d2.evaluation.evaluator]: Total inference time: 0:00:16.297948 (0.250738 s / img per device, on 1 devices)
# [02/26 11:24:50 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:15 (0.244742 s / img per device, on 1 devices)
# [02/26 11:24:50 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 11:24:50 d2.evaluation.coco_evaluation]: Saving results to ./output\For_rharel_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/26 11:24:50 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.633
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.985
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.762
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.487
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.623
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.688
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.050
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.475
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.694
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.686
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.747
# [02/26 11:24:50 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 63.288 | 98.496 | 76.216 | 48.688 | 62.270 | 68.810 |
# [02/26 11:24:50 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/26 11:24:50 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 11:24:50 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 11:24:50 d2.evaluation.testing]: copypaste: 63.2878,98.4964,76.2160,48.6883,62.2705,68.8096
# [02/26 11:24:50 d2.utils.events]:  eta: 0:24:19  iter: 599  total_loss: 0.507  loss_cls: 0.111  loss_box_reg: 0.330  loss_rpn_cls: 0.019  loss_rpn_loc: 0.033  time: 1.0546  data_time: 0.0016  lr: 0.019000  max_mem: 8056M
# [02/26 11:25:10 d2.utils.events]:  eta: 0:23:58  iter: 619  total_loss: 0.483  loss_cls: 0.102  loss_box_reg: 0.334  loss_rpn_cls: 0.017  loss_rpn_loc: 0.036  time: 1.0540  data_time: 0.0014  lr: 0.019000  max_mem: 8056M
# [02/26 11:25:31 d2.utils.events]:  eta: 0:23:37  iter: 639  total_loss: 0.519  loss_cls: 0.117  loss_box_reg: 0.337  loss_rpn_cls: 0.017  loss_rpn_loc: 0.035  time: 1.0536  data_time: 0.0016  lr: 0.019000  max_mem: 8056M
# [02/26 11:25:52 d2.utils.events]:  eta: 0:23:16  iter: 659  total_loss: 0.517  loss_cls: 0.108  loss_box_reg: 0.335  loss_rpn_cls: 0.023  loss_rpn_loc: 0.036  time: 1.0532  data_time: 0.0017  lr: 0.019000  max_mem: 8056M
# [02/26 11:26:13 d2.utils.events]:  eta: 0:22:55  iter: 679  total_loss: 0.557  loss_cls: 0.111  loss_box_reg: 0.365  loss_rpn_cls: 0.025  loss_rpn_loc: 0.040  time: 1.0528  data_time: 0.0016  lr: 0.019000  max_mem: 8056M
# [02/26 11:26:34 d2.data.datasets.coco]: Loaded 70 images in COCO format from X:/baboon/working/video/feeding\GH034137.json
# [02/26 11:26:34 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/26 11:26:34 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/26 11:26:34 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/26 11:26:34 d2.evaluation.evaluator]: Start inference on 70 images
# [02/26 11:26:38 d2.evaluation.evaluator]: Inference done 11/70. 0.2450 s / img. ETA=0:00:14
# [02/26 11:26:43 d2.evaluation.evaluator]: Inference done 32/70. 0.2453 s / img. ETA=0:00:09
# [02/26 11:26:48 d2.evaluation.evaluator]: Inference done 53/70. 0.2447 s / img. ETA=0:00:04
# [02/26 11:26:52 d2.evaluation.evaluator]: Total inference time: 0:00:16.303720 (0.250826 s / img per device, on 1 devices)
# [02/26 11:26:52 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:15 (0.244757 s / img per device, on 1 devices)
# [02/26 11:26:52 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 11:26:52 d2.evaluation.coco_evaluation]: Saving results to ./output\For_rharel_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/26 11:26:52 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.655
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.986
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.537
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.650
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.697
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.484
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.716
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.598
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.712
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.750
# [02/26 11:26:52 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 65.521 | 98.638 | 80.008 | 53.720 | 65.002 | 69.685 |
# [02/26 11:26:52 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/26 11:26:52 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 11:26:52 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 11:26:52 d2.evaluation.testing]: copypaste: 65.5206,98.6375,80.0082,53.7205,65.0023,69.6849
# [02/26 11:26:52 d2.utils.events]:  eta: 0:22:35  iter: 699  total_loss: 0.513  loss_cls: 0.114  loss_box_reg: 0.338  loss_rpn_cls: 0.022  loss_rpn_loc: 0.040  time: 1.0525  data_time: 0.0018  lr: 0.019000  max_mem: 8056M
# [02/26 11:27:13 d2.utils.events]:  eta: 0:22:14  iter: 719  total_loss: 0.478  loss_cls: 0.109  loss_box_reg: 0.327  loss_rpn_cls: 0.020  loss_rpn_loc: 0.030  time: 1.0521  data_time: 0.0014  lr: 0.019000  max_mem: 8056M
# [02/26 11:27:34 d2.utils.events]:  eta: 0:21:53  iter: 739  total_loss: 0.509  loss_cls: 0.122  loss_box_reg: 0.331  loss_rpn_cls: 0.020  loss_rpn_loc: 0.034  time: 1.0516  data_time: 0.0016  lr: 0.019000  max_mem: 8056M
# [02/26 11:27:55 d2.utils.events]:  eta: 0:21:32  iter: 759  total_loss: 0.485  loss_cls: 0.103  loss_box_reg: 0.309  loss_rpn_cls: 0.024  loss_rpn_loc: 0.035  time: 1.0513  data_time: 0.0015  lr: 0.019000  max_mem: 8056M
# [02/26 11:28:16 d2.utils.events]:  eta: 0:21:11  iter: 779  total_loss: 0.484  loss_cls: 0.108  loss_box_reg: 0.309  loss_rpn_cls: 0.019  loss_rpn_loc: 0.031  time: 1.0509  data_time: 0.0015  lr: 0.019000  max_mem: 8056M
# [02/26 11:28:36 d2.data.datasets.coco]: Loaded 70 images in COCO format from X:/baboon/working/video/feeding\GH034137.json
# [02/26 11:28:36 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/26 11:28:36 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/26 11:28:36 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/26 11:28:36 d2.evaluation.evaluator]: Start inference on 70 images
# [02/26 11:28:40 d2.evaluation.evaluator]: Inference done 11/70. 0.2446 s / img. ETA=0:00:14
# [02/26 11:28:45 d2.evaluation.evaluator]: Inference done 32/70. 0.2445 s / img. ETA=0:00:09
# [02/26 11:28:50 d2.evaluation.evaluator]: Inference done 53/70. 0.2445 s / img. ETA=0:00:04
# [02/26 11:28:55 d2.evaluation.evaluator]: Total inference time: 0:00:16.281497 (0.250485 s / img per device, on 1 devices)
# [02/26 11:28:55 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:15 (0.244517 s / img per device, on 1 devices)
# [02/26 11:28:55 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 11:28:55 d2.evaluation.coco_evaluation]: Saving results to ./output\For_rharel_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/26 11:28:55 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.01 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.796
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.503
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.646
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.704
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.051
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.485
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.707
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.585
# ...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.669
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.988
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.828
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.533
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.663
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.720
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.492
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.725
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.602
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.779
# [02/26 11:30:58 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 66.928 | 98.794 | 82.805 | 53.299 | 66.318 | 71.973 |
# [02/26 11:30:58 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/26 11:30:58 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 11:30:58 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 11:30:58 d2.evaluation.testing]: copypaste: 66.9281,98.7942,82.8050,53.2991,66.3184,71.9733
# [02/26 11:30:58 d2.utils.events]:  eta: 0:19:05  iter: 899  total_loss: 0.484  loss_cls: 0.106  loss_box_reg: 0.311  loss_rpn_cls: 0.018  loss_rpn_loc: 0.037  time: 1.0491  data_time: 0.0016  lr: 0.019000  max_mem: 8056M
# [02/26 11:31:18 d2.utils.events]:  eta: 0:18:44  iter: 919  total_loss: 0.505  loss_cls: 0.122  loss_box_reg: 0.327  loss_rpn_cls: 0.021  loss_rpn_loc: 0.032  time: 1.0489  data_time: 0.0014  lr: 0.019000  max_mem: 8056M
# [02/26 11:31:39 d2.utils.events]:  eta: 0:18:23  iter: 939  total_loss: 0.487  loss_cls: 0.112  loss_box_reg: 0.329  loss_rpn_cls: 0.016  loss_rpn_loc: 0.026  time: 1.0486  data_time: 0.0015  lr: 0.019000  max_mem: 8056M
# [02/26 11:32:00 d2.utils.events]:  eta: 0:18:02  iter: 959  total_loss: 0.459  loss_cls: 0.106  loss_box_reg: 0.315  loss_rpn_cls: 0.014  loss_rpn_loc: 0.026  time: 1.0483  data_time: 0.0013  lr: 0.019000  max_mem: 8056M
# [02/26 11:32:21 d2.utils.events]:  eta: 0:17:41  iter: 979  total_loss: 0.471  loss_cls: 0.105  loss_box_reg: 0.316  loss_rpn_cls: 0.016  loss_rpn_loc: 0.030  time: 1.0480  data_time: 0.0013  lr: 0.019000  max_mem: 8056M
# [02/26 11:32:41 d2.data.datasets.coco]: Loaded 70 images in COCO format from X:/baboon/working/video/feeding\GH034137.json
# [02/26 11:32:41 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/26 11:32:41 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/26 11:32:41 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/26 11:32:41 d2.evaluation.evaluator]: Start inference on 70 images
# [02/26 11:32:45 d2.evaluation.evaluator]: Inference done 11/70. 0.2447 s / img. ETA=0:00:14
# [02/26 11:32:50 d2.evaluation.evaluator]: Inference done 32/70. 0.2447 s / img. ETA=0:00:09
# [02/26 11:32:55 d2.evaluation.evaluator]: Inference done 53/70. 0.2446 s / img. ETA=0:00:04
# [02/26 11:33:00 d2.evaluation.evaluator]: Total inference time: 0:00:16.297351 (0.250728 s / img per device, on 1 devices)
# [02/26 11:33:00 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:15 (0.244665 s / img per device, on 1 devices)
# [02/26 11:33:00 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 11:33:00 d2.evaluation.coco_evaluation]: Saving results to ./output\For_rharel_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/26 11:33:00 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.683
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.989
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.862
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.566
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.681
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.738
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.625
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.734
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.775
# [02/26 11:33:00 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 68.311 | 98.877 | 86.245 | 56.607 | 68.119 | 71.508 |
# [02/26 11:33:00 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/26 11:33:00 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 11:33:00 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 11:33:00 d2.evaluation.testing]: copypaste: 68.3114,98.8765,86.2451,56.6073,68.1191,71.5080
# [02/26 11:33:00 d2.utils.events]:  eta: 0:17:20  iter: 999  total_loss: 0.448  loss_cls: 0.098  loss_box_reg: 0.303  loss_rpn_cls: 0.021  loss_rpn_loc: 0.029  time: 1.0477  data_time: 0.0014  lr: 0.019000  max_mem: 8056M
# [02/26 11:33:21 d2.utils.events]:  eta: 0:17:00  iter: 1019  total_loss: 0.413  loss_cls: 0.087  loss_box_reg: 0.281  loss_rpn_cls: 0.016  loss_rpn_loc: 0.032  time: 1.0476  data_time: 0.0015  lr: 0.019000  max_mem: 8056M
# [02/26 11:33:42 d2.utils.events]:  eta: 0:16:39  iter: 1039  total_loss: 0.429  loss_cls: 0.094  loss_box_reg: 0.297  loss_rpn_cls: 0.013  loss_rpn_loc: 0.030  time: 1.0474  data_time: 0.0018  lr: 0.019000  max_mem: 8056M
# [02/26 11:34:02 d2.utils.events]:  eta: 0:16:18  iter: 1059  total_loss: 0.415  loss_cls: 0.085  loss_box_reg: 0.298  loss_rpn_cls: 0.018  loss_rpn_loc: 0.027  time: 1.0472  data_time: 0.0014  lr: 0.019000  max_mem: 8056M
# [02/26 11:34:23 d2.utils.events]:  eta: 0:15:58  iter: 1079  total_loss: 0.436  loss_cls: 0.092  loss_box_reg: 0.287  loss_rpn_cls: 0.017  loss_rpn_loc: 0.031  time: 1.0471  data_time: 0.0019  lr: 0.019000  max_mem: 8056M
# [02/26 11:34:44 d2.data.datasets.coco]: Loaded 70 images in COCO format from X:/baboon/working/video/feeding\GH034137.json
# [02/26 11:34:44 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/26 11:34:44 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/26 11:34:44 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/26 11:34:44 d2.evaluation.evaluator]: Start inference on 70 images
# [02/26 11:34:48 d2.evaluation.evaluator]: Inference done 11/70. 0.2455 s / img. ETA=0:00:14
# [02/26 11:34:53 d2.evaluation.evaluator]: Inference done 32/70. 0.2457 s / img. ETA=0:00:09
# [02/26 11:34:58 d2.evaluation.evaluator]: Inference done 53/70. 0.2458 s / img. ETA=0:00:04
# [02/26 11:35:03 d2.evaluation.evaluator]: Total inference time: 0:00:16.376741 (0.251950 s / img per device, on 1 devices)
# [02/26 11:35:03 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:15 (0.245782 s / img per device, on 1 devices)
# [02/26 11:35:03 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 11:35:03 d2.evaluation.coco_evaluation]: Saving results to ./output\For_rharel_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/26 11:35:03 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.687
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.988
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.847
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.556
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.678
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.742
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.052
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.743
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.635
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.790
# [02/26 11:35:03 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 68.671 | 98.829 | 84.682 | 55.638 | 67.793 | 74.195 |
# [02/26 11:35:03 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/26 11:35:03 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 11:35:03 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 11:35:03 d2.evaluation.testing]: copypaste: 68.6709,98.8293,84.6821,55.6376,67.7935,74.1953
# [02/26 11:35:03 d2.utils.events]:  eta: 0:15:37  iter: 1099  total_loss: 0.442  loss_cls: 0.091  loss_box_reg: 0.291  loss_rpn_cls: 0.022  loss_rpn_loc: 0.032  time: 1.0468  data_time: 0.0017  lr: 0.019000  max_mem: 8056M
# [02/26 11:35:23 d2.utils.events]:  eta: 0:15:16  iter: 1119  total_loss: 0.437  loss_cls: 0.104  loss_box_reg: 0.294  loss_rpn_cls: 0.016  loss_rpn_loc: 0.028  time: 1.0467  data_time: 0.0015  lr: 0.019000  max_mem: 8056M
# [02/26 11:35:44 d2.utils.events]:  eta: 0:14:55  iter: 1139  total_loss: 0.429  loss_cls: 0.093  loss_box_reg: 0.296  loss_rpn_cls: 0.007  loss_rpn_loc: 0.024  time: 1.0465  data_time: 0.0016  lr: 0.019000  max_mem: 8056M
# [02/26 11:36:05 d2.utils.events]:  eta: 0:14:34  iter: 1159  total_loss: 0.453  loss_cls: 0.097  loss_box_reg: 0.308  loss_rpn_cls: 0.015  loss_rpn_loc: 0.030  time: 1.0463  data_time: 0.0012  lr: 0.019000  max_mem: 8056M
# [02/26 11:36:25 d2.utils.events]:  eta: 0:14:13  iter: 1179  total_loss: 0.456  loss_cls: 0.099  loss_box_reg: 0.288  loss_rpn_cls: 0.021  loss_rpn_loc: 0.034  time: 1.0460  data_time: 0.0012  lr: 0.019000  max_mem: 8056M
# [02/26 11:36:46 d2.data.datasets.coco]: Loaded 70 images in COCO format from X:/baboon/working/video/feeding\GH034137.json
# [02/26 11:36:46 d2.data.common]: Serializing 70 elements to byte tensors and concatenating them all ...
# [02/26 11:36:46 d2.data.common]: Serialized dataset takes 0.05 MiB
# [02/26 11:36:46 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/26 11:36:46 d2.evaluation.evaluator]: Start inference on 70 images
# [02/26 11:36:50 d2.evaluation.evaluator]: Inference done 11/70. 0.2447 s / img. ETA=0:00:14
# [02/26 11:36:55 d2.evaluation.evaluator]: Inference done 32/70. 0.2458 s / img. ETA=0:00:09
# [02/26 11:37:00 d2.evaluation.evaluator]: Inference done 53/70. 0.2454 s / img. ETA=0:00:04
# [02/26 11:37:05 d2.evaluation.evaluator]: Total inference time: 0:00:16.419972 (0.252615 s / img per device, on 1 devices)
# [02/26 11:37:05 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:16 (0.246576 s / img per device, on 1 devices)
# [02/26 11:37:05 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/26 11:37:05 d2.evaluation.coco_evaluation]: Saving results to ./output\For_rharel_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/26 11:37:05 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.00 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.690
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.988
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.562
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.687
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.728
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.744
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.623
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.736
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.792
# [02/26 11:37:05 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs   |  APm   |  APl   |
# |:------:|:------:|:------:|:------:|:------:|:------:|
# | 68.966 | 98.812 | 84.975 | 56.219 | 68.653 | 72.794 |
# [02/26 11:37:05 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/26 11:37:05 d2.evaluation.testing]: copypaste: Task: bbox
# [02/26 11:37:05 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/26 11:37:05 d2.evaluation.testing]: copypaste: 68.9660,98.8120,84.9753,56.2192,68.6533,72.7936
# [02/26 11:37:05 d2.utils.events]:  eta: 0:13:52  iter: 1199  total_loss: 0.459  loss_cls: 0.101  loss_box_reg: 0.293  loss_rpn_cls: 0.021  loss_rpn_loc: 0.035  time: 1.0458  data_time: 0.0012  lr: 0.019000  max_mem: 8056M
# [02/26 11:37:26 d2.utils.events]:  eta: 0:13:31  iter: 1219  total_loss: 0.447  loss_cls: 0.094  loss_box_reg: 0.296  loss_rpn_cls: 0.019  loss_rpn_loc: 0.029  time: 1.0458  data_time: 0.0012  lr: 0.019000  max_mem: 8056M
# [02/26 11:37:47 d2.utils.events]:  eta: 0:13:10  iter: 1239  total_loss: 0.462  loss_cls: 0.106  loss_box_reg: 0.308  loss_rpn_cls: 0.020  loss_rpn_loc: 0.033  time: 1.0457  data_time: 0.0015  lr: 0.019000  max_mem: 8056M
# [02/26 11:38:08 d2.utils.events]:  eta: 0:12:49  iter: 1259  total_loss: 0.443  loss_cls: 0.096  loss_box_reg: 0.296  loss_rpn_cls: 0.017  loss_rpn_loc: 0.032  time: 1.0459  data_time: 0.0014  lr: 0.019000  max_mem: 8056M
# [02/26 11:38:30 d2.utils.events]:  eta: 0:12:29  iter: 1279  total_loss: 0.422  loss_cls: 0.094  loss_box_reg: 0.276  loss_rpn_cls: 0.018  loss_rpn_loc: 0.035  time: 1.0466  data_time: 0.0019  lr: 0.019000  max_mem: 8056M

# %% [markdown]
# I ran the cell above once with all baboons set to class 'baboon' (which I did in the other script: convert-loopy-to-coco-JCL) and I got the error that there was a prediction with an category_id which didn't exist in the dataset. I am not sure how that would be possible.
#
# I then changed the number of classes above (cfg.MODEL.ROI_HEADS.NUM_CLASSES) from 3 to 1. I then got an error in the cell above that object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
#
# So I returned and to the previous script and set the classes back to normal 'baboon_small', 'baboon_medium', and 'baboon_large' and the num_classes above back to 3. I am still getting the numpy integer error.
#
# I looked on stackoverflow and saw that an older version of numpy might solve my problems, so I did a pip install of an older version of numpy and am trying to run again.

# %%
# Check training
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
cfg.DATASETS.TEST = ("train", )
predictor = DefaultPredictor(cfg)

# for d in random.sample(train_dicts, 3):
for d in train_dicts:
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=train_metadata,
                   scale=0.8,
                   
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    cv2_imshow(v.get_image()[:, :, ::-1])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-d610158c62ca> in <module>
#       3 cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
#       4 cfg.DATASETS.TEST = ("train", )
# ----> 5 predictor = DefaultPredictor(cfg)
#       6
#       7 # for d in random.sample(train_dicts, 3):
#
# c:\users\meerkat\detectron2-windows\detectron2\engine\defaults.py in __init__(self, cfg)
#     186
#     187         checkpointer = DetectionCheckpointer(self.model)
# --> 188         checkpointer.load(cfg.MODEL.WEIGHTS)
#     189
#     190         self.aug = T.ResizeShortestEdge(
#
# ~\anaconda3\lib\site-packages\fvcore\common\checkpoint.py in load(self, path, checkpointables)
#     139         if not os.path.isfile(path):
#     140             path = self.path_manager.get_local_path(path)
# --> 141             assert os.path.isfile(path), "Checkpoint {} not found!".format(path)
#     142
#     143         checkpoint = self._load_file(path)
#
# AssertionError: Checkpoint ./output\JCL_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\model_final.pth not found!

# %%
# Check validation
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
cfg.DATASETS.TEST = ("val", )
predictor = DefaultPredictor(cfg)

for d in val_dicts[:5]:
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=train_metadata,
                   scale=0.8,
                   
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    plt.figure()
    plt.imshow(v.get_image()[:, :, ::-1])

# %%
cfg.OUTPUT_DIR

# %%
print(cfg.MODEL, '\n')
