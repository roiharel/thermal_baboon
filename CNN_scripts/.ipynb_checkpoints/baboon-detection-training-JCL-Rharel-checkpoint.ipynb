# %%
import torch, torchvision
import detectron2
import os

from detectron2.utils.logger import setup_logger

import numpy as np
import cv2
import random

from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.evaluation import COCOEvaluator, DatasetEvaluators
# Out:
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath

# %%
print( np.__version__)
# Out:
# 1.17.4

# %%
import matplotlib.pyplot as plt

# %%
name = 'JCL'

# %%
def cv2_imshow(im):
    cv2.imshow('fiile', im)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
## root on my local computer
# root = 'C:/Users/cloftus/Documents/thermal_baboons/annotations/'

## root on the server
root = 'Y:/cloftus/analysis/thermal_baboon_project/'

from detectron2.data.datasets import register_coco_instances

output_folder = root + 'all_coco_annotations'
coco_annotation_file = os.path.join(output_folder, 'baboon_coco_annotations.json')
output_image_folder = os.path.join(output_folder, 'images')

register_coco_instances("train",  {}, coco_annotation_file, output_image_folder ) 
register_coco_instances("val", {}, coco_annotation_file, output_image_folder )

# %%
train_metadata = MetadataCatalog.get("train")

# %%
MetadataCatalog.get("val").evaluator_type
# Out:
# 'coco'

# %%
train_dicts = DatasetCatalog.get("train")
val_dicts = DatasetCatalog.get("val")

# %%
# for d in val_dicts:
#     img = cv2.imread(d["file_name"])
#     visualizer = Visualizer(img[:, :, ::-1], metadata=train_metadata, scale=0.5)
#     vis = visualizer.draw_dataset_dict(d)
#     cv2_imshow(vis.get_image()[:, :, ::-1])

# %%
# %matplotlib inline

for d in random.sample(train_dicts, 3):
# for d in train_dicts:
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=train_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    plt.figure(figsize=(10,10))
    plt.imshow(vis.get_image())
    plt.savefig('')

# %%
##base root on my local computer
#base_root = 'C:/Users/cloftus/'

##base root on the HiWi computer
base_root = 'C:/Users/meerkat/'

os.chdir( base_root + 'detectron2-windows/configs/COCO-Detection/' )

os.listdir()
# Out:
# ['faster_rcnn_R_101_C4_3x.yaml',
#  'faster_rcnn_R_101_DC5_3x.yaml',
#  'faster_rcnn_R_101_FPN_3x.yaml',
#  'faster_rcnn_R_50_C4_1x.yaml',
#  'faster_rcnn_R_50_C4_3x.yaml',
#  'faster_rcnn_R_50_DC5_1x.yaml',
#  'faster_rcnn_R_50_DC5_3x.yaml',
#  'faster_rcnn_R_50_FPN_1x.yaml',
#  'faster_rcnn_R_50_FPN_3x.yaml',
#  'faster_rcnn_X_101_32x8d_FPN_3x.yaml',
#  'fast_rcnn_R_50_FPN_1x.yaml',
#  'output',
#  'retinanet_R_101_FPN_3x.yaml',
#  'retinanet_R_50_FPN_1x.yaml',
#  'retinanet_R_50_FPN_3x.yaml',
#  'rpn_R_50_C4_1x.yaml',
#  'rpn_R_50_FPN_1x.yaml']

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
import os

cfg = get_cfg()
cfg.merge_from_file(
    base_root + 'detectron2-windows/configs/COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml'
)



cfg.DATASETS.TRAIN = ("train",)
cfg.DATASETS.TEST = ("val",)
cfg.DATALOADER.NUM_WORKERS = 6
cfg.DATALOADER.ASPECT_RATIO_GROUPING = False

cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url(
    "COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"
)
cfg.SOLVER.IMS_PER_BATCH = 8
cfg.SOLVER.BASE_LR = 0.019
cfg.SOLVER.MAX_ITER = (2000)
cfg.SOLVER.WARMUP_ITERS = 100
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = (256)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 3

cfg.TEST.EVAL_PERIOD = 100
cfg.TEST.DETECTIONS_PER_IMAGE = 200

cfg.INPUT.MIN_SIZE_TRAIN = (0)
cfg.INPUT.MIN_SIZE_TEST = (0)
cfg.INPUT.MAX_SIZE_TRAIN = (2871)
cfg.INPUT.MAX_SIZE_TEST = (2871)

cfg.INPUT.CROP.ENABLED = True
cfg.INPUT.CROP.TYPE = "absolute"
cfg.INPUT.CROP.SIZE = (720.0, 1280.0)
cfg.INPUT.VER_FLIP = True
cfg.INPUT.CONTRAST = True
cfg.INPUT.CONTRAST_RANGE = (.5, 1.5)
cfg.INPUT.BRIGHTNESS = True
cfg.INPUT.BRIGHTNESS_RANGE = (.4, 1.3)



cfg.OUTPUT_DIR = os.path.join(cfg.OUTPUT_DIR, '{}_maxiter-{}_lr-{}_detectPerIm-{}_minsize-{}_batchsize-{}'.format(
    name, cfg.SOLVER.MAX_ITER, cfg.SOLVER.BASE_LR, cfg.TEST.DETECTIONS_PER_IMAGE, 
    np.min(cfg.INPUT.MIN_SIZE_TRAIN), cfg.SOLVER.IMS_PER_BATCH))

# %%
cfg.OUTPUT_DIR
# Out:
# './output\\JCL_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8'

# %%
print(cfg.INPUT)
# Out:
# BRIGHTNESS: True
# BRIGHTNESS_RANGE: (0.4, 1.3)
# CONTRAST: True
# CONTRAST_RANGE: (0.5, 1.5)
# CROP:
#   ENABLED: True
#   SIZE: (720.0, 1280.0)
#   TYPE: absolute
# FORMAT: BGR
# MASK_FORMAT: polygon
# MAX_SIZE_TEST: 2871
# MAX_SIZE_TRAIN: 2871
# MIN_SIZE_TEST: 0
# MIN_SIZE_TRAIN: 0
# MIN_SIZE_TRAIN_SAMPLING: choice
# VER_FLIP: True

# %%
# mapper = MyDatasetMapper(cfg)
# loader = build_detection_train_loader(cfg, mapper=mapper)
# loader_iter = iter(loader)

# %%
# import matplotlib.pyplot as plt

# for im_num in range(4):

#     batch = next(loader_iter)

#     for im_dict in batch:
#         image = im_dict['image'].numpy()
#         image = np.transpose(image, [1, 2, 0])
#         image /= 255
#         cv2_imshow(image)

# %%
from detectron2.data import build_detection_train_loader
from detectron2.data import detection_utils as utils
from detectron2.data import transforms as T
from detectron2.data.dataset_mapper import DatasetMapper
import copy

import logging

import torch

class MyDatasetMapper(DatasetMapper):
    
    def __init__(self, cfg, is_train=True):
        if cfg.INPUT.CROP.ENABLED and is_train:
            self.crop_gen = T.RandomCrop(cfg.INPUT.CROP.TYPE, cfg.INPUT.CROP.SIZE)
            logging.getLogger(__name__).info("CropGen used in training: " + str(self.crop_gen))
        else:
            self.crop_gen = None

        self.tfm_gens = utils.build_transform_gen(cfg, is_train)
        
        if cfg.INPUT.VER_FLIP:
            self.tfm_gens.append(T.RandomFlip(vertical=True, horizontal=False))
        if cfg.INPUT.CONTRAST:
            self.tfm_gens.append(T.RandomContrast(*cfg.INPUT.CONTRAST_RANGE))
        if cfg.INPUT.BRIGHTNESS:
            self.tfm_gens.append(T.RandomBrightness(*cfg.INPUT.BRIGHTNESS_RANGE))
            
        logger = logging.getLogger(__name__)
        logger.info("TransformGens used in training: " + str(self.tfm_gens))

        # fmt: off
        self.img_format     = cfg.INPUT.FORMAT
        self.mask_on        = cfg.MODEL.MASK_ON
        self.mask_format    = cfg.INPUT.MASK_FORMAT
        self.keypoint_on    = cfg.MODEL.KEYPOINT_ON
        self.load_proposals = cfg.MODEL.LOAD_PROPOSALS
        # fmt: on
        
        if self.keypoint_on and is_train:
            # Flip only makes sense in training
            self.keypoint_hflip_indices = utils.create_keypoint_hflip_indices(cfg.DATASETS.TRAIN)
        else:
            self.keypoint_hflip_indices = None

        if self.load_proposals:
            self.min_box_side_len = cfg.MODEL.PROPOSAL_GENERATOR.MIN_SIZE
            self.proposal_topk = (
                cfg.DATASETS.PRECOMPUTED_PROPOSAL_TOPK_TRAIN
                if is_train
                else cfg.DATASETS.PRECOMPUTED_PROPOSAL_TOPK_TEST
            )

        self.is_train = is_train
    
    def __call__(self, dataset_dict):
        """
        Args:
            dataset_dict (dict): Metadata of one image, in Detectron2 Dataset format.
        Returns:
            dict: a format that builtin models in detectron2 accept
        """
        dataset_dict = copy.deepcopy(dataset_dict)  # it will be modified by code below
        # USER: Write your own image loading if it's not from a file
        image = utils.read_image(dataset_dict["file_name"], format=self.img_format)
        utils.check_image_size(dataset_dict, image)

        if "annotations" not in dataset_dict:
            image, transforms = T.apply_transform_gens(
                ([self.crop_gen] if self.crop_gen else []) + self.tfm_gens, image
            )
        else:
            # Crop around an instance if there are instances in the image.
            # USER: Remove if you don't use cropping
            if self.crop_gen:
                crop_tfm = utils.gen_crop_transform_with_instance(
                    self.crop_gen.get_crop_size(image.shape[:2]),
                    image.shape[:2],
                    np.random.choice(dataset_dict["annotations"]),
                )
                image = crop_tfm.apply_image(image)
            image, transforms = T.apply_transform_gens(self.tfm_gens, image)
            if self.crop_gen:
                transforms = crop_tfm + transforms

        image_shape = image.shape[:2]  # h, w

        # Pytorch's dataloader is efficient on torch.Tensor due to shared-memory,
        # but not efficient on large generic data structures due to the use of pickle & mp.Queue.
        # Therefore it's important to use torch.Tensor.
        dataset_dict["image"] = torch.as_tensor(
            image.transpose(2, 0, 1).astype("float32")
        ).contiguous()
        # Can use uint8 if it turns out to be slow some day

        if not self.is_train:
            dataset_dict.pop("annotations", None)
            dataset_dict.pop("sem_seg_file_name", None)
            return dataset_dict

        if "annotations" in dataset_dict:
            # USER: Modify this if you want to keep them for some reason.
            for anno in dataset_dict["annotations"]:
                if not self.mask_on:
                    anno.pop("segmentation", None)
                if not self.keypoint_on:
                    anno.pop("keypoints", None)
                    
            # USER: Implement additional transformations if you have other types of data
            annos = [
                utils.transform_instance_annotations(
                    obj, transforms, image_shape, keypoint_hflip_indices=self.keypoint_hflip_indices
                )
                for obj in dataset_dict.pop("annotations")
                if obj.get("iscrowd", 0) == 0
            ]
            instances = utils.annotations_to_instances(
                annos, image_shape, mask_format=self.mask_format
            )

            # Create a tight bounding box from masks, useful when image is cropped
            if self.crop_gen and instances.has("gt_masks"):
                instances.gt_boxes = instances.gt_masks.get_bounding_boxes()
            dataset_dict["instances"] = utils.filter_empty_instances(instances)

        return dataset_dict


class Trainer(DefaultTrainer):
    """ Implements build_evaluator. 
    Only for coco.
    """
    
    @classmethod
    def build_evaluator(cls, cfg, dataset_name, output_folder=None):
        if output_folder is None:
            output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
        evaluator_type = MetadataCatalog.get(dataset_name).evaluator_type
        if evaluator_type == "coco":
            return COCOEvaluator(dataset_name, cfg, True, output_folder)

        else:
            raise NotImplementedError("Only coco evaluators are currently implemented. Change build_evaluator().")
            
            
    @classmethod
    def build_train_loader(cls, cfg):
        """
        Returns:
            iterable
        It now calls :func:`detectron2.data.build_detection_train_loader` but now with mapper.
        Overwrite it if you'd like a different data loader.
        """
        
        mapper = MyDatasetMapper(cfg)
        
        return build_detection_train_loader(cfg, mapper=mapper)

# %%
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = Trainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/23 15:28:00 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=4, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=12, bias=True)
#     )
#   )
# )
# [02/23 15:28:01 d2.data.datasets.coco]: Loaded 976 images in COCO format from Y:/cloftus/analysis/thermal_baboon_project/all_coco_annotations\baboon_coco_annotations.json
# [02/23 15:28:01 d2.data.build]: Removed 1 images with no usable annotations. 975 images left.
# [02/23 15:28:01 d2.data.build]: Distribution of instances among all 3 categories:
# |   category   | #instances   |   category    | #instances   |   category   | #instances   |
# |:------------:|:-------------|:-------------:|:-------------|:------------:|:-------------|
# | baboon_large | 2013         | baboon_medium | 16384        | baboon_small | 10159        |
# |              |              |               |              |              |              |
# |    total     | 28556        |               |              |              |              |
# [02/23 15:28:01 d2.data.common]: Serializing 975 elements to byte tensors and concatenating them all ...
# [02/23 15:28:01 d2.data.common]: Serialized dataset takes 4.05 MiB
# [02/23 15:28:01 d2.data.build]: Using training sampler TrainingSampler
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (4, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (4,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (12, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (12,) in the model! You might want to double check if this is expected.
# [02/23 15:28:07 d2.engine.train_loop]: Starting training from iteration 0
# c:\users\meerkat\detectron2-windows\detectron2\layers\wrappers.py:226: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  ..\torch\csrc\utils\python_arg_parser.cpp:766.)
#   return x.nonzero().unbind(1)
# [02/23 15:30:52 d2.utils.events]:  eta: 1:33:25  iter: 19  total_loss: 1.860  loss_cls: 0.744  loss_box_reg: 0.700  loss_rpn_cls: 0.240  loss_rpn_loc: 0.154  time: 6.8445  data_time: 7.2315  lr: 0.003625  max_mem: 8056M
# [02/23 15:32:53 d2.utils.events]:  eta: 1:09:42  iter: 39  total_loss: 1.641  loss_cls: 0.644  loss_box_reg: 0.767  loss_rpn_cls: 0.104  loss_rpn_loc: 0.131  time: 6.4196  data_time: 5.1119  lr: 0.007422  max_mem: 8056M
# [02/23 15:34:55 d2.utils.events]:  eta: 0:32:34  iter: 59  total_loss: 1.446  loss_cls: 0.586  loss_box_reg: 0.663  loss_rpn_cls: 0.071  loss_rpn_loc: 0.114  time: 6.2986  data_time: 5.1338  lr: 0.011218  max_mem: 8056M
# [02/23 15:36:51 d2.utils.events]:  eta: 0:32:13  iter: 79  total_loss: 1.467  loss_cls: 0.568  loss_box_reg: 0.668  loss_rpn_cls: 0.073  loss_rpn_loc: 0.114  time: 6.1745  data_time: 4.8572  lr: 0.015014  max_mem: 8056M
# [02/23 15:38:53 d2.data.datasets.coco]: Loaded 976 images in COCO format from Y:/cloftus/analysis/thermal_baboon_project/all_coco_annotations\baboon_coco_annotations.json
# [02/23 15:38:53 d2.data.common]: Serializing 976 elements to byte tensors and concatenating them all ...
# [02/23 15:38:53 d2.data.common]: Serialized dataset takes 4.05 MiB
# [02/23 15:38:53 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/23 15:38:53 d2.evaluation.evaluator]: Start inference on 976 images
# [02/23 15:39:08 d2.evaluation.evaluator]: Inference done 11/976. 0.2645 s / img. ETA=0:07:07
# [02/23 15:39:15 d2.evaluation.evaluator]: Inference done 16/976. 0.2679 s / img. ETA=0:14:43
# [02/23 15:39:21 d2.evaluation.evaluator]: Inference done 27/976. 0.2646 s / img. ETA=0:10:58
# [02/23 15:39:26 d2.evaluation.evaluator]: Inference done 28/976. 0.2662 s / img. ETA=0:14:26
# [02/23 15:39:32 d2.evaluation.evaluator]: Inference done 39/976. 0.2675 s / img. ETA=0:12:03
# [02/23 15:39:39 d2.evaluation.evaluator]: Inference done 46/976. 0.2678 s / img. ETA=0:12:46
# [02/23 15:39:45 d2.evaluation.evaluator]: Inference done 52/976. 0.2673 s / img. ETA=0:13:09
# [02/23 15:39:51 d2.evaluation.evaluator]: Inference done 65/976. 0.2652 s / img. ETA=0:11:28
# [02/23 15:39:58 d2.evaluation.evaluator]: Inference done 74/976. 0.2650 s / img. ETA=0:11:31
# [02/23 15:40:03 d2.evaluation.evaluator]: Inference done 82/976. 0.2646 s / img. ETA=0:11:12
# [02/23 15:40:08 d2.evaluation.evaluator]: Inference done 97/976. 0.2636 s / img. ETA=0:10:02
# [02/23 15:40:14 d2.evaluation.evaluator]: Inference done 114/976. 0.2630 s / img. ETA=0:09:02
# [02/23 15:40:23 d2.evaluation.evaluator]: Inference done 120/976. 0.2634 s / img. ETA=0:09:36
# [02/23 15:40:28 d2.evaluation.evaluator]: Inference done 138/976. 0.2639 s / img. ETA=0:08:41
# [02/23 15:40:34 d2.evaluation.evaluator]: Inference done 144/976. 0.2641 s / img. ETA=0:08:50
# [02/23 15:40:41 d2.evaluation.evaluator]: Inference done 156/976. 0.2639 s / img. ETA=0:08:39
# [02/23 15:40:48 d2.evaluation.evaluator]: Inference done 164/976. 0.2638 s / img. ETA=0:08:44
# [02/23 15:40:55 d2.evaluation.evaluator]: Inference done 170/976. 0.2638 s / img. ETA=0:08:57
# [02/23 15:41:02 d2.evaluation.evaluator]: Inference done 176/976. 0.2635 s / img. ETA=0:09:06
# [02/23 15:41:11 d2.evaluation.evaluator]: Inference done 188/976. 0.2626 s / img. ETA=0:09:00
# [02/23 15:53:40 d2.data.datasets.coco]: Loaded 976 images in COCO format from Y:/cloftus/analysis/thermal_baboon_project/all_coco_annotations\baboon_coco_annotations.json
# [02/23 15:53:40 d2.data.common]: Serializing 976 elements to byte tensors and concatenating them all ...
# [02/23 15:53:40 d2.data.common]: Serialized dataset takes 4.05 MiB
# [02/23 15:53:40 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/23 15:53:41 d2.evaluation.evaluator]: Start inference on 976 images
# [02/23 15:53:52 d2.evaluation.evaluator]: Inference done 11/976. 0.2479 s / img. ETA=0:07:04
# [02/23 15:53:57 d2.evaluation.evaluator]: Inference done 20/976. 0.2485 s / img. ETA=0:08:31
# [02/23 15:54:03 d2.evaluation.evaluator]: Inference done 32/976. 0.2494 s / img. ETA=0:07:58
# [02/23 15:54:09 d2.evaluation.evaluator]: Inference done 44/976. 0.2495 s / img. ETA=0:07:48
# [02/23 15:54:14 d2.evaluation.evaluator]: Inference done 57/976. 0.2495 s / img. ETA=0:07:16
# [02/23 15:54:19 d2.evaluation.evaluator]: Inference done 77/976. 0.2497 s / img. ETA=0:06:11
# [02/23 15:54:24 d2.evaluation.evaluator]: Inference done 94/976. 0.2497 s / img. ETA=0:05:45
# [02/23 15:54:29 d2.evaluation.evaluator]: Inference done 113/976. 0.2497 s / img. ETA=0:05:19
# [02/23 15:54:35 d2.evaluation.evaluator]: Inference done 131/976. 0.2498 s / img. ETA=0:05:03
# [02/23 15:54:40 d2.evaluation.evaluator]: Inference done 149/976. 0.2498 s / img. ETA=0:04:49
# [02/23 15:54:45 d2.evaluation.evaluator]: Inference done 166/976. 0.2499 s / img. ETA=0:04:39
# [02/23 15:54:50 d2.evaluation.evaluator]: Inference done 185/976. 0.2500 s / img. ETA=0:04:26
# [02/23 15:54:55 d2.evaluation.evaluator]: Inference done 203/976. 0.2501 s / img. ETA=0:04:16
# [02/23 15:55:00 d2.evaluation.evaluator]: Inference done 218/976. 0.2502 s / img. ETA=0:04:12
# [02/23 15:55:05 d2.evaluation.evaluator]: Inference done 238/976. 0.2502 s / img. ETA=0:04:00
# [02/23 15:55:11 d2.evaluation.evaluator]: Inference done 257/976. 0.2503 s / img. ETA=0:03:51
# [02/23 15:55:16 d2.evaluation.evaluator]: Inference done 274/976. 0.2503 s / img. ETA=0:03:45
# [02/23 15:55:21 d2.evaluation.evaluator]: Inference done 293/976. 0.2504 s / img. ETA=0:03:36
# [02/23 15:55:26 d2.evaluation.evaluator]: Inference done 308/976. 0.2504 s / img. ETA=0:03:33
# [02/23 15:55:32 d2.evaluation.evaluator]: Inference done 326/976. 0.2504 s / img. ETA=0:03:26
# [02/23 15:55:37 d2.evaluation.evaluator]: Inference done 344/976. 0.2505 s / img. ETA=0:03:19
# [02/23 15:55:42 d2.evaluation.evaluator]: Inference done 362/976. 0.2505 s / img. ETA=0:03:14
# [02/23 15:55:47 d2.evaluation.evaluator]: Inference done 380/976. 0.2506 s / img. ETA=0:03:07
d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/23 16:02:15 d2.evaluation.evaluator]: Start inference on 976 images
# [02/23 16:02:28 d2.evaluation.evaluator]: Inference done 11/976. 0.2493 s / img. ETA=0:07:26
# [02/23 16:02:33 d2.evaluation.evaluator]: Inference done 19/976. 0.2489 s / img. ETA=0:08:57
# [02/23 16:02:39 d2.evaluation.evaluator]: Inference done 31/976. 0.2492 s / img. ETA=0:08:33
# [02/23 16:02:45 d2.evaluation.evaluator]: Inference done 43/976. 0.2497 s / img. ETA=0:08:18
# [02/23 16:02:50 d2.evaluation.evaluator]: Inference done 57/976. 0.2498 s / img. ETA=0:07:28
# [02/23 16:02:55 d2.evaluation.evaluator]: Inference done 74/976. 0.2499 s / img. ETA=0:06:38
# [02/23 16:03:01 d2.evaluation.evaluator]: Inference done 94/976. 0.2499 s / img. ETA=0:05:52
# [02/23 16:03:06 d2.evaluation.evaluator]: Inference done 111/976. 0.2500 s / img. ETA=0:05:31
# [02/23 16:03:11 d2.evaluation.evaluator]: Inference done 127/976. 0.2500 s / img. ETA=0:05:19
# [02/23 16:03:16 d2.evaluation.evaluator]: Inference done 144/976. 0.2500 s / img. ETA=0:05:05
# [02/23 16:03:21 d2.evaluation.evaluator]: Inference done 161/976. 0.2500 s / img. ETA=0:04:52
# [02/23 16:03:26 d2.evaluation.evaluator]: Inference done 181/976. 0.2501 s / img. ETA=0:04:36
# [02/23 16:03:31 d2.evaluation.evaluator]: Inference done 199/976. 0.2502 s / img. ETA=0:04:25
# [02/23 16:03:36 d2.evaluation.evaluator]: Inference done 216/976. 0.2503 s / img. ETA=0:04:16
# [02/23 16:03:41 d2.evaluation.evaluator]: Inference done 231/976. 0.2503 s / img. ETA=0:04:11
# [02/23 16:03:46 d2.evaluation.evaluator]: Inference done 249/976. 0.2504 s / img. ETA=0:04:02
# [02/23 16:03:52 d2.evaluation.evaluator]: Inference done 269/976. 0.2504 s / img. ETA=0:03:51
# [02/23 16:03:57 d2.evaluation.evaluator]: Inference done 289/976. 0.2505 s / img. ETA=0:03:41
# [02/23 16:04:02 d2.evaluation.evaluator]: Inference done 309/976. 0.2506 s / img. ETA=0:03:32
# [02/23 16:04:07 d2.evaluation.evaluator]: Inference done 327/976. 0.2506 s / img. ETA=0:03:25
# [02/23 16:04:12 d2.evaluation.evaluator]: Inference done 345/976. 0.2507 s / img. ETA=0:03:18
# [02/23 16:04:17 d2.evaluation.evaluator]: Inference done 362/976. 0.2507 s / img. ETA=0:03:13
# [02/23 16:04:23 d2.evaluation.evaluator]: Inference done 379/976. 0.2508 s / img. ETA=0:03:07
# [02/23 16:06:54 d2.evaluation.evaluator]: Inference done 892/976. 0.2517 s / img. ETA=0:00:25
# [02/23 16:06:59 d2.evaluation.evaluator]: Inference done 912/976. 0.2518 s / img. ETA=0:00:19
# [02/23 16:07:04 d2.evaluation.evaluator]: Inference done 929/976. 0.2518 s / img. ETA=0:00:14
# [02/23 16:07:09 d2.evaluation.evaluator]: Inference done 946/976. 0.2518 s / img. ETA=0:00:09
# [02/23 16:07:14 d2.evaluation.evaluator]: Inference done 966/976. 0.2518 s / img. ETA=0:00:03
# [02/23 16:07:17 d2.evaluation.evaluator]: Total inference time: 0:04:52.121923 (0.300846 s / img per device, on 1 devices)
# [02/23 16:07:17 d2.evaluation.evaluator]: Total inference pure compute time: 0:04:04 (0.251817 s / img per device, on 1 devices)
# [02/23 16:07:18 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/23 16:07:18 d2.evaluation.coco_evaluation]: Saving results to ./output\JCL_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/23 16:07:19 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.53s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 1.33 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.33 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.289
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.120
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.034
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.207
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.199
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.415
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.262
# [02/23 16:07:21 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 11.090 | 28.939 | 5.830  | 6.571 | 12.024 | 10.421 |
# [02/23 16:07:21 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category     | AP    | category      | AP     | category     | AP    |
# |:-------------|:------|:--------------|:-------|:-------------|:------|
# | baboon_large | 6.544 | baboon_medium | 18.255 | baboon_small | 8.472 |
# [02/23 16:07:21 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/23 16:07:21 d2.evaluation.testing]: copypaste: Task: bbox
# ...
# [02/23 16:13:44 d2.evaluation.evaluator]: Inference done 499/976. 0.2509 s / img. ETA=0:02:28
# [02/23 16:13:49 d2.evaluation.evaluator]: Inference done 516/976. 0.2509 s / img. ETA=0:02:23
# [02/23 16:13:55 d2.evaluation.evaluator]: Inference done 535/976. 0.2509 s / img. ETA=0:02:16
# [02/23 16:14:00 d2.evaluation.evaluator]: Inference done 552/976. 0.2510 s / img. ETA=0:02:11
# [02/23 16:14:05 d2.evaluation.evaluator]: Inference done 571/976. 0.2510 s / img. ETA=0:02:04
# [02/23 16:14:10 d2.evaluation.evaluator]: Inference done 591/976. 0.2510 s / img. ETA=0:01:57
# [02/23 16:14:15 d2.evaluation.evaluator]: Inference done 610/976. 0.2511 s / img. ETA=0:01:51
# [02/23 16:14:20 d2.evaluation.evaluator]: Inference done 630/976. 0.2512 s / img. ETA=0:01:45
# [02/23 16:14:25 d2.evaluation.evaluator]: Inference done 649/976. 0.2512 s / img. ETA=0:01:38
# [02/23 16:14:31 d2.evaluation.evaluator]: Inference done 668/976. 0.2513 s / img. ETA=0:01:32
# [02/23 16:14:36 d2.evaluation.evaluator]: Inference done 687/976. 0.2513 s / img. ETA=0:01:27
# [02/23 16:14:42 d2.evaluation.evaluator]: Inference done 706/976. 0.2513 s / img. ETA=0:01:21
# [02/23 16:14:47 d2.evaluation.evaluator]: Inference done 723/976. 0.2514 s / img. ETA=0:01:16
# [02/23 16:14:52 d2.evaluation.evaluator]: Inference done 743/976. 0.2514 s / img. ETA=0:01:09
# [02/23 16:14:57 d2.evaluation.evaluator]: Inference done 759/976. 0.2514 s / img. ETA=0:01:05
# [02/23 16:15:03 d2.evaluation.evaluator]: Inference done 777/976. 0.2515 s / img. ETA=0:00:59
# [02/23 16:15:08 d2.evaluation.evaluator]: Inference done 794/976. 0.2515 s / img. ETA=0:00:54
# [02/23 16:15:13 d2.evaluation.evaluator]: Inference done 811/976. 0.2515 s / img. ETA=0:00:49
# [02/23 16:15:18 d2.evaluation.evaluator]: Inference done 830/976. 0.2516 s / img. ETA=0:00:43
# [02/23 16:15:23 d2.evaluation.evaluator]: Inference done 850/976. 0.2516 s / img. ETA=0:00:37
# [02/23 16:15:29 d2.evaluation.evaluator]: Inference done 868/976. 0.2516 s / img. ETA=0:00:32
# [02/23 16:15:34 d2.evaluation.evaluator]: Inference done 883/976. 0.2517 s / img. ETA=0:00:27
# [02/23 16:15:39 d2.evaluation.evaluator]: Inference done 901/976. 0.2517 s / img. ETA=0:00:22
# [02/23 16:15:44 d2.evaluation.evaluator]: Inference done 915/976. 0.2517 s / img. ETA=0:00:18
# [02/23 16:15:49 d2.evaluation.evaluator]: Inference done 933/976. 0.2518 s / img. ETA=0:00:12
# [02/23 16:15:54 d2.evaluation.evaluator]: Inference done 949/976. 0.2518 s / img. ETA=0:00:08
# [02/23 16:15:59 d2.evaluation.evaluator]: Inference done 965/976. 0.2518 s / img. ETA=0:00:03
# [02/23 16:16:03 d2.evaluation.evaluator]: Total inference time: 0:04:52.229144 (0.300957 s / img per device, on 1 devices)
# [02/23 16:16:03 d2.evaluation.evaluator]: Total inference pure compute time: 0:04:04 (0.251793 s / img per device, on 1 devices)
# [02/23 16:16:04 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/23 16:16:04 d2.evaluation.coco_evaluation]: Saving results to ./output\JCL_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/23 16:16:04 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.75s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 1.26 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.32 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.146
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.387
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.075
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.067
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.168
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.138
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.239
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.385
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.182
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.404
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.317
# [02/23 16:16:07 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 14.610 | 38.738 | 7.499  | 6.657 | 16.812 | 13.762 |
# [02/23 16:16:07 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category     | AP     | category      | AP     | category     | AP     |
# |:-------------|:-------|:--------------|:-------|:-------------|:-------|
# | baboon_large | 12.316 | baboon_medium | 21.158 | baboon_small | 10.357 |
# [02/23 16:16:07 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/23 16:16:07 d2.evaluation.testing]: copypaste: Task: bbox
# [02/23 16:16:07 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/23 16:16:07 d2.evaluation.testing]: copypaste: 14.6103,38.7377,7.4994,6.6571,16.8121,13.7617
# [02/23 16:16:07 d2.utils.events]:  eta: 0:25:06  iter: 399  total_loss: 1.322  loss_cls: 0.498  loss_box_reg: 0.628  loss_rpn_cls: 0.049  loss_rpn_loc: 0.119  time: 3.1807  data_time: 1.5066  lr: 0.019000  max_mem: 8056M
# [02/23 16:16:34 d2.utils.events]:  eta: 0:24:46  iter: 419  total_loss: 1.215  loss_cls: 0.492  loss_box_reg: 0.605  loss_rpn_cls: 0.053  loss_rpn_loc: 0.110  time: 3.0923  data_time: 0.3993  lr: 0.019000  max_mem: 8056M
# [02/23 16:17:19 d2.utils.events]:  eta: 0:24:29  iter: 439  total_loss: 1.240  loss_cls: 0.485  loss_box_reg: 0.590  loss_rpn_cls: 0.045  loss_rpn_loc: 0.119  time: 3.0542  data_time: 1.3230  lr: 0.019000  max_mem: 8056M
# [02/23 16:18:07 d2.utils.events]:  eta: 0:24:15  iter: 459  total_loss: 1.167  loss_cls: 0.466  loss_box_reg: 0.576  loss_rpn_cls: 0.042  loss_rpn_loc: 0.107  time: 3.0270  data_time: 1.4993  lr: 0.019000  max_mem: 8056M
# [02/23 16:19:00 d2.utils.events]:  eta: 0:24:00  iter: 479  total_loss: 1.298  loss_cls: 0.504  loss_box_reg: 0.614  loss_rpn_cls: 0.055  loss_rpn_loc: 0.121  time: 3.0092  data_time: 1.6663  lr: 0.019000  max_mem: 8056M
# [02/23 16:19:49 d2.data.datasets.coco]: Loaded 976 images in COCO format from Y:/cloftus/analysis/thermal_baboon_project/all_coco_annotations\baboon_coco_annotations.json
# [02/23 16:19:49 d2.data.common]: Serializing 976 elements to byte tensors and concatenating them all ...
# [02/23 16:19:49 d2.data.common]: Serialized dataset takes 4.05 MiB
# [02/23 16:19:49 d2.data.dataset_mapper]: Augmentations used in training: [ResizeShortestEdge(short_edge_length=(0, 0), max_size=2871, sample_style='choice')]
# [02/23 16:19:49 d2.evaluation.evaluator]: Start inference on 976 images
# [02/23 16:20:04 d2.evaluation.evaluator]: Inference done 11/976. 0.2528 s / img. ETA=0:09:50
# [02/23 16:20:09 d2.evaluation.evaluator]: Inference done 20/976. 0.2513 s / img. ETA=0:10:06
# [02/23 16:20:15 d2.evaluation.evaluator]: Inference done 33/976. 0.2505 s / img. ETA=0:08:15
# [02/23 16:20:21 d2.evaluation.evaluator]: Inference done 44/976. 0.2509 s / img. ETA=0:08:28
# [02/23 16:20:27 d2.evaluation.evaluator]: Inference done 56/976. 0.2512 s / img. ETA=0:08:08
# [02/23 16:20:32 d2.evaluation.evaluator]: Inference done 76/976. 0.2508 s / img. ETA=0:06:47
# [02/23 16:20:37 d2.evaluation.evaluator]: Inference done 95/976. 0.2506 s / img. ETA=0:06:05
# [02/23 16:20:42 d2.evaluation.evaluator]: Inference done 110/976. 0.2505 s / img. ETA=0:05:50
# [02/23 16:20:48 d2.evaluation.evaluator]: Inference done 129/976. 0.2504 s / img. ETA=0:05:25
# [02/23 16:20:53 d2.evaluation.evaluator]: Inference done 144/976. 0.2503 s / img. ETA=0:05:16
# [02/23 16:20:58 d2.evaluation.evaluator]: Inference done 164/976. 0.2503 s / img. ETA=0:04:55
# [02/23 16:21:03 d2.evaluation.evaluator]: Inference done 184/976. 0.2503 s / img. ETA=0:04:38
# [02/23 16:21:08 d2.evaluation.evaluator]: Inference done 201/976. 0.2504 s / img. ETA=0:04:29
# [02/23 16:21:13 d2.evaluation.evaluator]: Inference done 217/976. 0.2506 s / img. ETA=0:04:22
# [02/23 16:21:18 d2.evaluation.evaluator]: Inference done 236/976. 0.2506 s / img. ETA=0:04:11
# [02/23 16:21:23 d2.evaluation.evaluator]: Inference done 255/976. 0.2506 s / img. ETA=0:04:00
# [02/23 16:21:29 d2.evaluation.evaluator]: Inference done 271/976. 0.2507 s / img. ETA=0:03:56
# [02/23 16:21:34 d2.evaluation.evaluator]: Inference done 290/976. 0.2511 s / img. ETA=0:03:47
# [02/23 16:21:39 d2.evaluation.evaluator]: Inference done 307/976. 0.2513 s / img. ETA=0:03:40
# [02/23 16:21:45 d2.evaluation.evaluator]: Inference done 325/976. 0.2515 s / img. ETA=0:03:33
# [02/23 16:21:50 d2.evaluation.evaluator]: Inference done 342/976. 0.2517 s / img. ETA=0:03:27
# [02/23 16:21:55 d2.evaluation.evaluator]: Inference done 358/976. 0.2524 s / img. ETA=0:03:21
# [02/23 16:22:00 d2.evaluation.evaluator]: Inference done 375/976. 0.2527 s / img. ETA=0:03:15
# [02/23 16:22:05 d2.evaluation.evaluator]: Inference done 394/976. 0.2529 s / img. ETA=0:03:07
# [02/23 16:22:11 d2.evaluation.evaluator]: Inference done 411/976. 0.2532 s / img. ETA=0:03:01
# [02/23 16:22:16 d2.evaluation.evaluator]: Inference done 430/976. 0.2536 s / img. ETA=0:02:54
# [02/23 16:22:21 d2.evaluation.evaluator]: Inference done 448/976. 0.2537 s / img. ETA=0:02:48
# [02/23 16:22:26 d2.evaluation.evaluator]: Inference done 463/976. 0.2538 s / img. ETA=0:02:43
# [02/23 16:22:31 d2.evaluation.evaluator]: Inference done 479/976. 0.2537 s / img. ETA=0:02:38
# [02/23 16:22:37 d2.evaluation.evaluator]: Inference done 499/976. 0.2539 s / img. ETA=0:02:31
# [02/23 16:22:42 d2.evaluation.evaluator]: Inference done 517/976. 0.2538 s / img. ETA=0:02:25
# [02/23 16:22:47 d2.evaluation.evaluator]: Inference done 529/976. 0.2538 s / img. ETA=0:02:23
# [02/23 16:22:53 d2.evaluation.evaluator]: Inference done 547/976. 0.2538 s / img. ETA=0:02:16
# [02/23 16:22:58 d2.evaluation.evaluator]: Inference done 567/976. 0.2537 s / img. ETA=0:02:09
# [02/23 16:23:03 d2.evaluation.evaluator]: Inference done 585/976. 0.2539 s / img. ETA=0:02:03
# [02/23 16:23:08 d2.evaluation.evaluator]: Inference done 604/976. 0.2540 s / img. ETA=0:01:57
# [02/23 16:23:14 d2.evaluation.evaluator]: Inference done 623/976. 0.2540 s / img. ETA=0:01:50
# [02/23 16:23:19 d2.evaluation.evaluator]: Inference done 641/976. 0.2541 s / img. ETA=0:01:44
# [02/23 16:23:24 d2.evaluation.evaluator]: Inference done 660/976. 0.2542 s / img. ETA=0:01:38
# [02/23 16:23:29 d2.evaluation.evaluator]: Inference done 678/976. 0.2543 s / img. ETA=0:01:32
# [02/23 16:23:34 d2.evaluation.evaluator]: Inference done 693/976. 0.2544 s / img. ETA=0:01:28
# [02/23 16:23:39 d2.evaluation.evaluator]: Inference done 713/976. 0.2545 s / img. ETA=0:01:21
# [02/23 16:23:44 d2.evaluation.evaluator]: Inference done 732/976. 0.2547 s / img. ETA=0:01:15
# [02/23 16:23:49 d2.evaluation.evaluator]: Inference done 743/976. 0.2549 s / img. ETA=0:01:12
# [02/23 16:23:54 d2.evaluation.evaluator]: Inference done 757/976. 0.2552 s / img. ETA=0:01:08
# [02/23 16:24:00 d2.evaluation.evaluator]: Inference done 772/976. 0.2554 s / img. ETA=0:01:03
# [02/23 16:24:05 d2.evaluation.evaluator]: Inference done 789/976. 0.2555 s / img. ETA=0:00:58
# [02/23 16:24:10 d2.evaluation.evaluator]: Inference done 806/976. 0.2557 s / img. ETA=0:00:53
# [02/23 16:24:15 d2.evaluation.evaluator]: Inference done 824/976. 0.2559 s / img. ETA=0:00:47
# [02/23 16:24:20 d2.evaluation.evaluator]: Inference done 842/976. 0.2560 s / img. ETA=0:00:41
# [02/23 16:24:26 d2.evaluation.evaluator]: Inference done 860/976. 0.2562 s / img. ETA=0:00:36
# [02/23 16:24:31 d2.evaluation.evaluator]: Inference done 878/976. 0.2563 s / img. ETA=0:00:30
# [02/23 16:24:36 d2.evaluation.evaluator]: Inference done 891/976. 0.2563 s / img. ETA=0:00:26
# [02/23 16:24:41 d2.evaluation.evaluator]: Inference done 907/976. 0.2564 s / img. ETA=0:00:21
# [02/23 16:24:46 d2.evaluation.evaluator]: Inference done 921/976. 0.2564 s / img. ETA=0:00:17
# [02/23 16:24:51 d2.evaluation.evaluator]: Inference done 934/976. 0.2565 s / img. ETA=0:00:13
# [02/23 16:24:57 d2.evaluation.evaluator]: Inference done 950/976. 0.2565 s / img. ETA=0:00:08
# [02/23 16:25:03 d2.evaluation.evaluator]: Inference done 967/976. 0.2566 s / img. ETA=0:00:02
# [02/23 16:25:07 d2.evaluation.evaluator]: Total inference time: 0:05:06.675111 (0.315834 s / img per device, on 1 devices)
# [02/23 16:25:07 d2.evaluation.evaluator]: Total inference pure compute time: 0:04:09 (0.256612 s / img per device, on 1 devices)
# [02/23 16:25:07 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/23 16:25:07 d2.evaluation.coco_evaluation]: Saving results to ./output\JCL_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\inference\coco_instances_results.json
# [02/23 16:25:08 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.43s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 1.11 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.27 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.173
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.420
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.110
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.071
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.154
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.057
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.411
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.292
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.441
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.285
# [02/23 16:25:10 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 17.348 | 41.994 | 11.026 | 7.071 | 18.577 | 15.440 |
# [02/23 16:25:10 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category     | AP     | category      | AP     | category     | AP     |
# |:-------------|:-------|:--------------|:-------|:-------------|:-------|
# | baboon_large | 16.922 | baboon_medium | 22.846 | baboon_small | 12.276 |
# [02/23 16:25:10 d2.engine.defaults]: Evaluation results for val in csv format:
# [02/23 16:25:10 d2.evaluation.testing]: copypaste: Task: bbox
# [02/23 16:25:10 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/23 16:25:10 d2.evaluation.testing]: copypaste: 17.3478,41.9941,11.0257,7.0705,18.5767,15.4403
# [02/23 16:25:10 d2.utils.events]:  eta: 0:23:43  iter: 499  total_loss: 1.216  loss_cls: 0.464  loss_box_reg: 0.602  loss_rpn_cls: 0.044  loss_rpn_loc: 0.107  time: 2.9855  data_time: 1.4799  lr: 0.019000  max_mem: 8056M
# [02/23 16:25:45 d2.utils.events]:  eta: 0:23:31  iter: 519  total_loss: 1.246  loss_cls: 0.469  loss_box_reg: 0.600  loss_rpn_cls: 0.047  loss_rpn_loc: 0.106  time: 2.9375  data_time: 0.7795  lr: 0.019000  max_mem: 8056M
# [02/23 16:26:39 d2.utils.events]:  eta: 0:23:15  iter: 539  total_loss: 1.198  loss_cls: 0.438  loss_box_reg: 0.595  loss_rpn_cls: 0.043  loss_rpn_loc: 0.109  time: 2.9295  data_time: 1.7658  lr: 0.019000  max_mem: 8056M
# [02/23 16:27:31 d2.utils.events]:  eta: 0:22:57  iter: 559  total_loss: 1.186  loss_cls: 0.428  loss_box_reg: 0.584  loss_rpn_cls: 0.040  loss_rpn_loc: 0.114  time: 2.9169  data_time: 1.6132  lr: 0.019000  max_mem: 8056M

# %% [markdown]
# I ran the cell above once with all baboons set to class 'baboon' (which I did in the other script: convert-loopy-to-coco-JCL) and I got the error that there was a prediction with an category_id which didn't exist in the dataset. I am not sure how that would be possible.
#
# I then changed the number of classes above (cfg.MODEL.ROI_HEADS.NUM_CLASSES) from 3 to 1. I then got an error in the cell above that object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
#
# So I returned and to the previous script and set the classes back to normal 'baboon_small', 'baboon_medium', and 'baboon_large' and the num_classes above back to 3. I am still getting the numpy integer error.
#
# I looked on stackoverflow and saw that an older version of numpy might solve my problems, so I did a pip install of an older version of numpy and am trying to run again.

# %%
# Check training
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
cfg.DATASETS.TEST = ("train", )
predictor = DefaultPredictor(cfg)

# for d in random.sample(train_dicts, 3):
for d in train_dicts:
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=train_metadata,
                   scale=0.8,
                   
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    cv2_imshow(v.get_image()[:, :, ::-1])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-19-d610158c62ca> in <module>
#       3 cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
#       4 cfg.DATASETS.TEST = ("train", )
# ----> 5 predictor = DefaultPredictor(cfg)
#       6
#       7 # for d in random.sample(train_dicts, 3):
#
# c:\users\meerkat\detectron2-windows\detectron2\engine\defaults.py in __init__(self, cfg)
#     186
#     187         checkpointer = DetectionCheckpointer(self.model)
# --> 188         checkpointer.load(cfg.MODEL.WEIGHTS)
#     189
#     190         self.aug = T.ResizeShortestEdge(
#
# ~\anaconda3\lib\site-packages\fvcore\common\checkpoint.py in load(self, path, checkpointables)
#     139         if not os.path.isfile(path):
#     140             path = self.path_manager.get_local_path(path)
# --> 141             assert os.path.isfile(path), "Checkpoint {} not found!".format(path)
#     142
#     143         checkpoint = self._load_file(path)
#
# AssertionError: Checkpoint ./output\JCL_maxiter-2000_lr-0.019_detectPerIm-200_minsize-0_batchsize-8\model_final.pth not found!

# %%
# Check validation
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
cfg.DATASETS.TEST = ("val", )
predictor = DefaultPredictor(cfg)

for d in val_dicts[:5]:
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=train_metadata,
                   scale=0.8,
                   
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    plt.figure()
    plt.imshow(v.get_image()[:, :, ::-1])

# %%
cfg.OUTPUT_DIR

# %%
print(cfg.MODEL, '\n')
